# %%
from read_graph import read_ID_map, read_link_graph

TITLES_TO_IDS, IDS_TO_TILES = read_ID_map("data/ID_map.txt")
GRAPH = read_link_graph("data/link_graph_ids.txt")
# Out:
# Reading ID Map: 100%|██████████| 16714619/16714619 [00:12<00:00, 1311829.93it/s]
# Reading Graph: 100%|██████████| 16833643/16833643 [00:43<00:00, 384383.20it/s]

# %%
import search

import importlib
importlib.reload(search)

search.GRAPH = GRAPH
search.TITLES_TO_IDS = TITLES_TO_IDS
search.IDS_TO_TILES = IDS_TO_TILES

# %%
from tqdm import tqdm
import timeit
from helpers import fetch_page_html, find_link_text_in_html

def solve_wiki_game(start, goal, method="BFS"):
    start_time = timeit.default_timer()
    path = search.shortest_path(start, goal, method=method)
    stop_time = timeit.default_timer()
    print()
    print(f"({(stop_time-start_time)*1000:.0f} ms)")

    print("Raw Path:  ", "  ->  ".join(path))
    print()

    # link_texts = [""]
    # # for i in tqdm(range(len(path)-1), desc="Fetching Link Texts", leave=False):
    # for i in range(len(path)-1):
    #     page_a, page_b = path[i], path[i+1]
    #     html = fetch_page_html(page_a)
    #     link_text = find_link_text_in_html(html, page_b)
    #     if link_text is None:
    #         link_text = "NOT_FOUND"
    #     link_texts.append(link_text)
    
    # block_widths = [max(len(title), len(lt)+2) for title, lt in zip(path, link_texts)]
    # print("Solution:   " + "  ->  ".join(title.center(w) for title, w in zip(path, block_widths)))
    # print(" "*(block_widths[0] + 18), end="")
    # print("      ".join(("\"" + lt + "\"").center(w) for lt, w in zip(link_texts[1:], block_widths[1:])))


METHODS = ("BFS", "IDS", "A* dummy")

# %%
start = "Babe_Ruth"
goal = "Coastal_California"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (916 ms)
# Raw Path:   Babe_Ruth  ->  Herbert_Hoover  ->  Monterey,_California  ->  Coastal_California
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (1437 ms)
# Raw Path:   Babe_Ruth  ->  Herbert_Hoover  ->  Monterey,_California  ->  Coastal_California
#
#
# Searching using method: A* dummy
#
# (5742 ms)
# Raw Path:   Babe_Ruth  ->  The_New_York_Times  ->  California  ->  Coastal_California

# %%
start = "Marbles"
goal = "Eiffel_Tower"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (47 ms)
# Raw Path:   Marbles  ->  Marble_(toy)  ->  Alabaster  ->  Paris  ->  Eiffel_Tower
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
# Searching depth 4 ...
#
# (30 ms)
# Raw Path:   Marbles  ->  Marble_(toy)  ->  Alabaster  ->  Paris  ->  Eiffel_Tower
#
#
# Searching using method: A* dummy
#
# (1103 ms)
# Raw Path:   Marbles  ->  Marble_(toy)  ->  Plastic  ->  European_Union  ->  Eiffel_Tower

# %%
start = "Benito_Mussolini"
goal = "Mickey_Mouse"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (203 ms)
# Raw Path:   Benito_Mussolini  ->  Alps  ->  Berghof_(residence)  ->  Mickey_Mouse
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (192 ms)
# Raw Path:   Benito_Mussolini  ->  Alps  ->  Berghof_(residence)  ->  Mickey_Mouse
#
#
# Searching using method: A* dummy
#
# (2995 ms)
# Raw Path:   Benito_Mussolini  ->  Racial_segregation  ->  Academy_Awards  ->  Mickey_Mouse

# %%
start = "Elon_Musk"
goal = "Carnegie_Mellon"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (291 ms)
# Raw Path:   Elon_Musk  ->  PayPal  ->  Micropayment  ->  Carnegie_Mellon
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (303 ms)
# Raw Path:   Elon_Musk  ->  PayPal  ->  Micropayment  ->  Carnegie_Mellon
#
#
# Searching using method: A* dummy
#
# (1427 ms)
# Raw Path:   Elon_Musk  ->  PayPal  ->  Micropayment  ->  Carnegie_Mellon

# %%
start = "Chuck_E._Cheese"
goal = "Methamphetamine"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (212 ms)
# Raw Path:   Chuck_E._Cheese  ->  Colombia  ->  Cocaine  ->  Methamphetamine
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (199 ms)
# Raw Path:   Chuck_E._Cheese  ->  Colombia  ->  Cocaine  ->  Methamphetamine
#
#
# Searching using method: A* dummy
#
# (4241 ms)
# Raw Path:   Chuck_E._Cheese  ->  Colombia  ->  Cocaine  ->  Methamphetamine

# %%
start = "Cocaine"
goal = "Methamphetamine"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (0 ms)
# Raw Path:   Cocaine  ->  Methamphetamine
#
#
# Searching using method: IDS
# Searching depth 1 ...
#
# (0 ms)
# Raw Path:   Cocaine  ->  Methamphetamine
#
#
# Searching using method: A* dummy
#
# (18 ms)
# Raw Path:   Cocaine  ->  Methamphetamine

# %%
start = "Genghis_Khan"
goal = "Meditation"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (62 ms)
# Raw Path:   Genghis_Khan  ->  Hong_Kong  ->  Confucianism  ->  Meditation
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (49 ms)
# Raw Path:   Genghis_Khan  ->  Hong_Kong  ->  Confucianism  ->  Meditation
#
#
# Searching using method: A* dummy
#
# (822 ms)
# Raw Path:   Genghis_Khan  ->  Hong_Kong  ->  Confucianism  ->  Meditation

# %%
start = "Doritos"
goal = "Shrek"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (373 ms)
# Raw Path:   Doritos  ->  The_Onion  ->  Computer_animation  ->  Shrek
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (385 ms)
# Raw Path:   Doritos  ->  The_Onion  ->  Computer_animation  ->  Shrek
#
#
# Searching using method: A* dummy
#
# (3811 ms)
# Raw Path:   Doritos  ->  Wayne's_World_(film)  ->  Comedy_film  ->  Shrek

# %%
start = "Carnegie_Mellon_University"
goal = "Shrek"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (96 ms)
# Raw Path:   Carnegie_Mellon_University  ->  List_of_Carnegie_Mellon_University_people  ->  Shrek
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
#
# (69 ms)
# Raw Path:   Carnegie_Mellon_University  ->  List_of_Carnegie_Mellon_University_people  ->  Shrek

# %%
start = "Poop"
goal = "Cheese"

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# Searching using method: BFS
#
# (6 ms)
# Raw Path:   Poop  ->  Feces  ->  Enzyme  ->  Cheese
#
#
# Searching using method: IDS
# Searching depth 1 ...
# Searching depth 2 ...
# Searching depth 3 ...
#
# (3 ms)
# Raw Path:   Poop  ->  Feces  ->  Enzyme  ->  Cheese

# %%
from random import randint

start = IDS_TO_TILES[randint(0, 16_000_000)]
goal = IDS_TO_TILES[randint(0, 16_000_000)]

print(f"{start} -> ??? -> {goal}")

for method in METHODS:
    print(f"Searching using method: {method}")
    solve_wiki_game(start, goal, method)
    print()
# Out:
# School_of_Sound_Recording -> ??? -> 2014-15_Primera_Divisio
# Searching using method: BFS
# 	Searched: 500000
# 	Searched: 1000000
# 	Searched: 1500000
# 	Searched: 2000000
# 	Searched: 2500000
# 	Searched: 3000000
# 	Searched: 3500000
# 	Searched: 4000000
# 	Searched: 4500000
# 	Searched: 5000000
# 	Searched: 5500000
# 	Searched: 6000000
# 	Searched: 6500000
# 	Searched: 7000000
# 	Searched: 7500000
# 	Searched: 8000000
# 	Searched: 8500000
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/j3/_k92zpq172d0p68rq5kvdbsc0000gn/T/ipykernel_80382/3398911808.py", line 10, in <module>
#     solve_wiki_game(start, goal, method)
#   File "/var/folders/j3/_k92zpq172d0p68rq5kvdbsc0000gn/T/ipykernel_80382/285076463.py", line 7, in solve_wiki_game
#     path = search.shortest_path(start, goal, method=method)
#   File "/Users/russ/Misc/Wikipedia-Link-Network/Link-Graph/search.py", line 125, in shortest_path
#   File "/Users/russ/Misc/Wikipedia-Link-Network/Link-Graph/search.py", line 38, in shortest_path_BFS_id
#     continue
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/Users/russ/.pyenv/versions/3.10.7/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# # Record for most-distant pages
#
# **8 hops:** `Linear_inequality -> Convex_set -> Crescent -> Switzerland -> Economy_of_Switzerland -> List_of_banks_in_Switzerland -> List_of_banks_(alphabetically) -> List_of_banks_(alphabetical) -> Metrocorp_Bancshares`
