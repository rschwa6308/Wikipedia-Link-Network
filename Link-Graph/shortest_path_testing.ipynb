# %%
from read_graph import read_ID_map, read_link_graph
from helpers import build_transpose_graph

TITLES_TO_IDS, IDS_TO_TILES = read_ID_map("data/ID_map.txt")
GRAPH = read_link_graph("data/link_graph_IDs.txt")
# TRANSPOSE_GRAPH = build_transpose_graph(GRAPH)
# Out:
# Reading ID Map: 100%|██████████| 16714619/16714619 [00:29<00:00, 572374.50it/s]
# Reading Graph: 100%|██████████| 16833643/16833643 [01:09<00:00, 241296.42it/s]

# %%
import importlib

import search
importlib.reload(search)

unit_tests = [("Andrew_Carnegie", "Shrek"),
              ("Babe_Ruth", "Coastal_California"),
              ("Marbles", "Eiffel_Tower"),
              ("Benito_Mussolini", "Mickey_Mouse"),
              ("Elon_Musk", "Carnegie_Mellon"),
              ("Chuck_E._Cheese", "Carnegie_Mellon"),
              ("Cocaine", "Methamphetamine"),
              ("Genghis_Khan", "Meditation"),
              ("Doritos", "Shrek"),
              ("Carnegie_Mellon_University", "Shrek"),
              ("Poop", "Cheese")]

def print_search_results(test_results):
    #first element is path 
    if test_results[0] != None:
        print("\nRaw Path:  ", "  ->  ".join(test_results[0]))
    else:
        print("\nNo solution found")
    print("time elapsed: " + str(test_results[1]) + " secs. nodes expanded: " + str(test_results[2]))

# %%
from bfs import BFS_Search

for test in unit_tests:
    bfs_test = BFS_Search(GRAPH, TITLES_TO_IDS, IDS_TO_TILES)
    results = bfs_test.shortest_path(test[0], test[1])
    print_search_results(results)
# Out:
# Raw Path:   Andrew_Carnegie  ->  Winston_Churchill  ->  John_Lithgow  ->  Shrek
# time elapsed: 3.93 secs. nodes expanded: 16439
#
# Raw Path:   Babe_Ruth  ->  Herbert_Hoover  ->  Monterey,_California  ->  Coastal_California
# time elapsed: 1.97 secs. nodes expanded: 8476
#
# Raw Path:   Marbles  ->  Marble_(toy)  ->  Alabaster  ->  Paris  ->  Eiffel_Tower
# time elapsed: 0.09 secs. nodes expanded: 120
#
# Raw Path:   Benito_Mussolini  ->  Alps  ->  Berghof_(residence)  ->  Mickey_Mouse
# time elapsed: 0.44 secs. nodes expanded: 1317
#
# Raw Path:   Elon_Musk  ->  PayPal  ->  Micropayment  ->  Carnegie_Mellon
# time elapsed: 0.64 secs. nodes expanded: 1888
#
# Raw Path:   Chuck_E._Cheese  ->  North_America  ->  Great_Lakes_megalopolis  ->  Carnegie_Mellon
# time elapsed: 1.58 secs. nodes expanded: 5033
#
# Raw Path:   Cocaine  ->  Methamphetamine
# time elapsed: 0.0 secs. nodes expanded: 1
#
# Raw Path:   Genghis_Khan  ->  Hong_Kong  ->  Confucianism  ->  Meditation
# time elapsed: 0.15 secs. nodes expanded: 506
#
# Raw Path:   Doritos  ->  The_Onion  ->  Computer_animation  ->  Shrek
# time elapsed: 0.87 secs. nodes expanded: 2337
#
# Raw Path:   Carnegie_Mellon_University  ->  List_of_Carnegie_Mellon_University_people  ->  Shrek
# time elapsed: 0.22 secs. nodes expanded: 532
#
# Raw Path:   Poop  ->  Feces  ->  Enzyme  ->  Cheese
# time elapsed: 0.02 secs. nodes expanded: 22

# %%
import ids
importlib.reload(ids)

for test in unit_tests:
    ids_test = ids.ID_Search(GRAPH, TITLES_TO_IDS, IDS_TO_TILES)
    results = ids_test.shortest_path(test[0], test[1])
    print_search_results(results)
# Out:
# Raw Path:   Andrew_Carnegie  ->  Winston_Churchill  ->  John_Lithgow  ->  Shrek
# time elapsed: 5.826449661999504 secs. nodes expanded: 3270484
#
# Raw Path:   Babe_Ruth  ->  Herbert_Hoover  ->  Monterey,_California  ->  Coastal_California
# time elapsed: 2.968483454998932 secs. nodes expanded: 1664972
#
# Raw Path:   Marbles  ->  Marble_(toy)  ->  Alabaster  ->  Paris  ->  Eiffel_Tower
# time elapsed: 0.0573392039987084 secs. nodes expanded: 32596
#
# Raw Path:   Benito_Mussolini  ->  Alps  ->  Berghof_(residence)  ->  Mickey_Mouse
# time elapsed: 0.3902222780016018 secs. nodes expanded: 221509
#
# Raw Path:   Elon_Musk  ->  PayPal  ->  Micropayment  ->  Carnegie_Mellon
# time elapsed: 0.713170770999568 secs. nodes expanded: 347945
#
# Raw Path:   Chuck_E._Cheese  ->  North_America  ->  Great_Lakes_megalopolis  ->  Carnegie_Mellon
# time elapsed: 2.054110765999212 secs. nodes expanded: 1078359
#
# Raw Path:   Cocaine  ->  Methamphetamine
# time elapsed: 0.00017889800074044615 secs. nodes expanded: 116
#
# Raw Path:   Genghis_Khan  ->  Hong_Kong  ->  Confucianism  ->  Meditation
# time elapsed: 0.0961470449983608 secs. nodes expanded: 56420
#
# Raw Path:   Doritos  ->  The_Onion  ->  Computer_animation  ->  Shrek
# time elapsed: 0.8178955000003043 secs. nodes expanded: 452248
#
# Raw Path:   Carnegie_Mellon_University  ->  List_of_Carnegie_Mellon_University_people  ->  Shrek
# time elapsed: 0.14563239600101952 secs. nodes expanded: 82127
#
# Raw Path:   Poop  ->  Feces  ->  Enzyme  ->  Cheese
# time elapsed: 0.007484836998628452 secs. nodes expanded: 3646
